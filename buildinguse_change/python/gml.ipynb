# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('data/53392546_bldg_4326_lod0.geojson')

# %%
gdf.plot(figsize=(10, 10))
# Out:
# <AxesSubplot: >

# %%
gdf.head()
# Out:
#                                           id 大字・町コード 町・丁目コード  \
# 0  bldg_fc50c7d9-76ac-4576-bfbd-f37c74410928      49       3
# 1  bldg_2e11a57e-c315-4351-8cca-22649d9763dc      33       4
# 2  bldg_72de059a-ddf0-4959-be00-db8108ca4a3a      38       4
# 3  bldg_2297d74f-b3d5-410a-b62c-a41f6913758c      38       4
# 4  bldg_f6edafc1-b722-4b15-90e3-393cbb64d998      49       3
#
#   13+区市町村コード+大字・町コード+町・丁目コード measured_height_uom  measured_height  \
# 0                13111049003                   m              8.3
# 1                13111033004                   m              9.9
# 2                13111038004                   m              7.8
# 3                13111038004                   m              9.5
# 4                13111049003                   m              6.5
#
#   address_type       address                     filename mesh_code object  \
# 0         Town  東京都大田区東六郷三丁目  53392546_bldg_6697_2_op.gml  53392546   bldg
# ...
